# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# Library Import
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import pandas as pd
import os

# %%
# Get current working directory
cwd = os.getcwd()
print(cwd)
# Out:
# /Users/uditanand/Desktop/Github/GooglePracticum

# %%
# Import Names of counties from file

maize_data_dir = cwd + '/Data/Maize/'
IL_county_data = maize_data_dir + 'County_Name_IL_updated.csv'

#IL_county_data = 'County_Name_IL_updated.csv'
county_data = pd.read_csv(IL_county_data)

# rename Ag district to Ag_District
county_data.rename(columns={'Ag District': 'Ag_District'}, inplace=True)

# making all column names UPPER CASE --> inline with the weather data file
county_data.columns = map(str.upper, county_data.columns)

# making COUNTY, STATE, AG DISTRICT, COMMODITY data lower case
# CAN BE MADE FASTER WITH A LAMBDA FUNCTION
county_data.STATE = county_data.STATE.str.lower()
county_data.AG_DISTRICT = county_data.AG_DISTRICT.str.lower()
county_data.COUNTY = county_data.COUNTY.str.lower() 
county_data.COMMODITY = county_data.COMMODITY.str.lower()

print(county_data.head())

# Print name of unique districts
ag_district_list = list(county_data['AG_DISTRICT'].unique())
print(" \n Agricultural Districts: \n")
print(ag_district_list)
# Out:
#       STATE AG_DISTRICT      COUNTY COMMODITY     VALUE
# 0  illinois     central      mclean      corn  63008000
# 1  illinois     central       logan      corn  41005000
# 2  illinois     central       macon      corn  30430000
# 3  illinois        east    iroquois      corn  62773000
# 4  illinois        east  livingston      corn  54632000
#
#  Agricultural Districts:
#
# ['central', 'east', 'east southeast', 'northeast', 'northwest', 'southeast', 'southwest', 'west', 'west southwest']

# %%
# Group counties belonging to a particular agricultural district and store them in a dictionary

district_county_dict = {}

for district in ag_district_list:
    county_in_ag_district = county_data[(county_data['AG_DISTRICT'] == district)] 
    county_in_ag_district = county_in_ag_district['COUNTY']
    district_county_dict[district] = county_in_ag_district

# Print the dictionary, Structure {Region_1: County_1, County_2 ,... ; Region_2: County_1, County_2.. }
for key,values in district_county_dict.items():
    print(key)
    print(values)
    print("\n")
# Out:
# central
# 0    mclean
# 1     logan
# 2     macon
# Name: COUNTY, dtype: object
#
#
# east
# 3      iroquois
# 4    livingston
# 5     champaign
# Name: COUNTY, dtype: object
#
#
# east southeast
# 6     shelby
# 7      edgar
# 8    douglas
# Name: COUNTY, dtype: object
#
#
# northeast
# 9     la salle
# 10     de kalb
# 11      grundy
# Name: COUNTY, dtype: object
#
#
# northwest
# 12    bureau
# 13      ogle
# 14       lee
# Name: COUNTY, dtype: object
#
#
# southeast
# 15       white
# 16       wayne
# 17    gallatin
# Name: COUNTY, dtype: object
#
#
# southwest
# 18    washington
# 19      st clair
# 20       clinton
# Name: COUNTY, dtype: object
#
#
# west
# 21       knox
# 22    hancock
# 23     warren
# Name: COUNTY, dtype: object
#
#
# west southwest
# 24     sangamon
# 25    christian
# 26     macoupin
# Name: COUNTY, dtype: object

# %%
# Import weather data file
weather_data_dir = cwd + '/Data/Weather/'
weather_file = weather_data_dir + 'weather_data.csv'
weather_data = pd.read_csv(weather_file)

print("\n Column Information \n")
print(weather_data.columns.all)
# Out:
#  Column Information
#
# <bound method Index._add_logical_methods.<locals>._make_logical_function.<locals>.logical_func of Index(['INDEX', 'COUNTY', 'YEAR', 'MONTH', 'TMP_HIGH', 'TMP_AVG', 'TMP_LOW',
#        'DP_HIGH', 'DP_AVG', 'DP_LOW', 'HUM_HIGH', 'HUM_AVG', 'HUM_LOW',
#        'SEALVL_HIGH', 'SEALVL_AVG', 'SEALVL_LOW', 'VIS_HIGH', 'VIS_AVG',
#        'VIS_LOW', 'WIND_HIGH', 'WIND_AVG', 'PRECIP', 'NUMDAY_RAIN',
#        'NUM_DAYS_SNOW', 'NUM_DAYS_FOG', 'NUM_DAYS_THNDRSTRM'],
#       dtype='object')>

# %%
# Append corresponding AGRICULTURAL DISTRICT to COUNTY
weather_data['AG_DISTRICT'] = "Dummy"

# Added by Sid
# weather_data.drop('Unnamed: 0', axis=1, inplace=True)

# reorder the AG_DISTRICT to become the first column
colnames = weather_data.columns.tolist()
colnames = colnames[-1:] + colnames[:-1]
weather_data = weather_data[colnames]

county_names_list = list(county_data['COUNTY'].unique())

for county in county_names_list:
    county_district = county_data[(county_data['COUNTY'] == county)] 
    county_district = county_district['AG_DISTRICT']
    
    selected_county = weather_data[(weather_data['COUNTY'] == county)]
    
    weather_data.loc[weather_data['COUNTY'] == county, 'AG_DISTRICT'] = county_district.values

weather_data = weather_data[weather_data.AG_DISTRICT != 'Dummy']
weather_data.loc[:,['AG_DISTRICT','COUNTY']].head()
weather_data.head()

#print(weather_data.columns.all)

#weather_data.iloc[:,5:26]
# Out:
#   AG_DISTRICT  INDEX  COUNTY  YEAR MONTH  TMP_HIGH    TMP_AVG  TMP_LOW  \
# 0     central      0  mclean  2001   JAN      41.0  24.935484      3.0
# 1     central      1  mclean  2001   FEB      57.0  28.964286     -2.0
# 2     central      2  mclean  2001   MAR      59.0  36.225806     15.0
# 3     central      3  mclean  2001   ARP      84.0  57.533333     28.0
# 4     central      4  mclean  2001   MAY      89.0  63.935484     44.0
#
#    DP_HIGH     DP_AVG         ...          VIS_HIGH    VIS_AVG  VIS_LOW  \
# 0     37.0  22.032258         ...              20.0   7.774194      0.0
# 1     55.0  22.892857         ...              20.0   9.464286      0.0
# 2     50.0  26.193548         ...              20.0  11.000000      1.0
# 3     68.0  42.566667         ...              20.0  12.033333      1.0
# 4     68.0  51.709677         ...              20.0  10.580645      0.0
#
#    WIND_HIGH   WIND_AVG  PRECIP  NUMDAY_RAIN  NUM_DAYS_SNOW  NUM_DAYS_FOG  \
# 0       21.0   9.322581     0.0          5.0           10.0           4.0
# 1       24.0  10.035714     0.0          7.0            7.0           2.0
# 2       20.0   9.322581     0.0          6.0            5.0           1.0
# 3       23.0  10.466667     0.0          8.0            1.0           0.0
# 4       25.0   8.129032     0.0         11.0            0.0           2.0
#
#    NUM_DAYS_THNDRSTRM
# 0                 0.0
# 1                 3.0
# 2                 0.0
# 3                 3.0
# 4                 2.0
#
# [5 rows x 27 columns]

# %%
months = list(weather_data['MONTH'].unique())
months
# Out:
# ['JAN',
#  'FEB',
#  'MAR',
#  'ARP',
#  'MAY',
#  'JUN',
#  'JUL',
#  'AUG',
#  'SEP',
#  'OCT',
#  'NOV',
#  'DEC']

# %%
groupby_year_mth_ag_district = weather_data.groupby(['YEAR', 'MONTH','AG_DISTRICT'])
groupby_year_mth_ag_district_df = groupby_year_mth_ag_district['NUMDAY_RAIN', 'NUM_DAYS_SNOW', 'NUM_DAYS_THNDRSTRM','NUM_DAYS_SNOW','NUM_DAYS_FOG','PRECIP'].sum()

# Writes to Excel
# writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')
# Convert the dataframe to an XlsxWriter Excel object.
# sample_data.to_excel(writer, sheet_name='Sheet1')
# Close the Pandas Excel writer and output the Excel file.
# writer.save()

groupby_year_mth_ag_district_df.iloc[:,:]
# Out:
#                            NUMDAY_RAIN  NUM_DAYS_SNOW  NUM_DAYS_THNDRSTRM  \
# YEAR MONTH AG_DISTRICT
# 2001 ARP   central                14.0           10.0                 3.0
#            east                   21.0            0.0                 9.0
#            east southeast         10.0            0.0                 6.0
#            northeast              26.0            0.0                18.0
#            northwest               0.0            0.0                 7.0
#            southeast               2.0            0.0                 7.0
#            southwest              16.0            0.0                24.0
#            west                    0.0            0.0                 0.0
#            west southwest         20.0            2.0                10.0
#      AUG   central                 8.0            0.0                 4.0
#            east                   13.0            0.0                 6.0
#            east southeast         13.0            0.0                 6.0
#            northwest               0.0            0.0                 5.0
#            southwest               8.0            0.0                 7.0
#            west                    0.0            0.0                 0.0
#            west southwest         13.0            0.0                 7.0
#      DEC   central                 6.0            9.0                 0.0
#            east                    8.0           10.0                 0.0
#            east southeast          8.0           10.0                 0.0
#            northwest               0.0            0.0                 1.0
#            southwest              11.0            4.0                 0.0
#            west                    0.0            0.0                 0.0
#            west southwest          7.0            8.0                 1.0
#      FEB   central                 7.0            8.0                 4.0
#            east                    9.0           10.0                 4.0
#            east southeast          9.0           10.0                 4.0
#            northeast               1.0            0.0                 0.0
#            northwest               6.0            9.0                 2.0
#            southeast               0.0            0.0                 0.0
#            southwest              11.0            7.0                 3.0
# ...                                ...            ...                 ...
# 2016 MAY   southwest              57.0            0.0                32.0
#            west                   39.0            0.0                20.0
#            west southwest         45.0            0.0                24.0
#      NOV   central                15.0            0.0                 6.0
#            east                   26.0            1.0                 4.0
#            east southeast         24.0            0.0                 6.0
#            northeast              23.0            2.0                 5.0
#            northwest              24.0            3.0                 6.0
#            southeast              15.0            0.0                 2.0
#            southwest              24.0            0.0                 7.0
#            west                   19.0            0.0                 4.0
#            west southwest         24.0            2.0                11.0
#      OCT   central                18.0            0.0                 9.0
#            east                   29.0            0.0                14.0
#            east southeast         22.0            0.0                13.0
#            northeast              32.0            0.0                20.0
#            northwest              36.0            0.0                17.0
#            southeast              11.0            0.0                 6.0
#            southwest              18.0            0.0                12.0
#            west                   26.0            0.0                12.0
#            west southwest         26.0            0.0                21.0
#      SEP   central                25.0            0.0                10.0
#            east                   37.0            0.0                16.0
#            east southeast         32.0            0.0                20.0
#            northeast              42.0            0.0                15.0
#            northwest              31.0            0.0                17.0
#            southeast               9.0            0.0                 9.0
#            southwest              29.0            0.0                23.0
#            west                   24.0            0.0                 8.0
#            west southwest         26.0            0.0                12.0
#
#                            NUM_DAYS_SNOW  NUM_DAYS_FOG  PRECIP
# YEAR MONTH AG_DISTRICT
# 2001 ARP   central                  10.0           3.0   1.030
#            east                      0.0           2.0   1.830
#            east southeast            0.0           0.0   5.960
#            northeast                 0.0           4.0   5.080
#            northwest                 0.0           0.0   3.170
#            southeast                 0.0           0.0  11.360
#            southwest                 0.0           0.0   7.200
#            west                      0.0           0.0   0.000
#            west southwest            2.0           1.0   3.540
#      AUG   central                   0.0           2.0   0.000
#            east                      0.0           6.0   5.330
#            east southeast            0.0           6.0   5.330
#            northwest                 0.0           0.0   5.620
#            southwest                 0.0           0.0   2.950
#            west                      0.0           0.0   0.000
#            west southwest            0.0           8.0   3.180
#      DEC   central                   9.0           7.0   0.000
#            east                     10.0           7.0   1.750
#            east southeast           10.0           7.0   1.750
#            northwest                 0.0           0.0   0.100
#            southwest                 4.0           3.0   4.160
#            west                      0.0           0.0   0.000
#            west southwest            8.0           7.0   1.860
#      FEB   central                   8.0           2.0   0.030
#            east                     10.0           8.0   4.660
#            east southeast           10.0           6.0   5.280
#            northeast                 0.0           1.0   3.490
#            northwest                 9.0           4.0   1.560
#            southeast                 0.0           0.0   2.540
#            southwest                 7.0           4.0   6.960
# ...                                  ...           ...     ...
# 2016 MAY   southwest                 0.0           8.0  11.730
#            west                      0.0          13.0   7.890
#            west southwest            0.0           7.0   7.685
#      NOV   central                   0.0           7.0   3.530
#            east                      1.0          10.0   6.615
#            east southeast            0.0           5.0   6.595
#            northeast                 2.0          11.0   6.180
#            northwest                 3.0          11.0   5.100
#            southeast                 0.0           4.0   5.510
#            southwest                 0.0          11.0   7.390
#            west                      0.0           8.0   5.570
#            west southwest            2.0           5.0   5.185
#      OCT   central                   0.0           1.0   2.280
#            east                      0.0           5.0   4.395
#            east southeast            0.0           7.0   5.095
#            northeast                 0.0           3.0   7.530
#            northwest                 0.0           2.0   4.840
#            southeast                 0.0           2.0   1.110
#            southwest                 0.0           4.0   8.150
#            west                      0.0           7.0   5.420
#            west southwest            0.0           6.0   4.070
#      SEP   central                   0.0           5.0   7.390
#            east                      0.0           7.0  10.385
#            east southeast            0.0           9.0   8.535
#            northeast                 0.0           7.0   6.200
#            northwest                 0.0           8.0   4.160
#            southeast                 0.0          10.0   4.510
#            southwest                 0.0          23.0  16.330
#            west                      0.0           4.0   4.190
#            west southwest            0.0           6.0   6.725
#
# [1716 rows x 6 columns]

# %%
# Precipitation is measured in inches.

start_year = min(weather_data['YEAR'])
end_year = max(weather_data['YEAR'])

# end year + 1 to get it to 2016
for year in range(start_year, end_year+1):
    groupby_yearly = weather_data[weather_data['YEAR'] == year].groupby(['AG_DISTRICT', 'YEAR'])
    groupby_yearly_ppt_data = groupby_yearly['PRECIP'].sum()
    
    # Average value for the district composed of three counties.
    # groupby_yearly_ppt_data = groupby_yearly_ppt_data/3
    
    print(groupby_yearly_ppt_data)
    
    # Calculate average precipitation for the given year
    size = groupby_yearly_ppt_data.count()
    average_precipitation = sum(groupby_yearly_ppt_data.iloc[:size].values)/(size)
    print ("\n Average: " + str(average_precipitation) + "\n")
    
    # Plotting Code
    precp_yearly_title = str(year) + ": Average Yearly Precipitation received across various districts (in inches)."
    line_label = "Average Precipitation for the year " + str(year) 
    
    plt.figure(figsize=(15,7))
    plt.suptitle(precp_yearly_title, fontsize=16, fontweight='bold')
    ax1 = groupby_yearly_ppt_data.plot(kind='bar', label ='Precipitation')
    ax2 = plt.hlines(average_precipitation,-2,10, colors='r', linestyles='solid', label=line_label)
    plt.xticks(rotation=45)
    plt.ylabel('Inches', fontsize=16)
    plt.xlabel('Agricultural Districts', fontsize=16)
    plt.legend()
    #plt.savefig("results.jpg")
    plt.show()
    
    # 2008 validation
    # http://www.isws.illinois.edu/atmos/statecli/climate-change/NE-IL-trends/rainfall.htm
# Out:
# AG_DISTRICT     YEAR
# central         2001     2.77
# east            2001    36.61
# east southeast  2001    44.68
# northeast       2001    19.34
# northwest       2001    22.36
# southeast       2001    31.86
# southwest       2001    57.23
# west            2001     4.64
# west southwest  2001    34.72
# Name: PRECIP, dtype: float64
#
#  Average: 28.2455555556
# AG_DISTRICT     YEAR
# central         2002    31.29
# east            2002    59.82
# east southeast  2002    82.81
# northeast       2002    50.21
# northwest       2002    50.21
# southeast       2002    43.07
# southwest       2002    79.53
# west            2002    31.96
# west southwest  2002    71.99
# Name: PRECIP, dtype: float64
#
#  Average: 55.6544444444
# AG_DISTRICT     YEAR
# central         2003    20.63
# east            2003    51.01
# east southeast  2003    70.53
# northeast       2003    45.46
# northwest       2003    74.41
# southeast       2003    40.07
# southwest       2003    86.94
# west            2003    58.90
# west southwest  2003    56.98
# Name: PRECIP, dtype: float64
#
#  Average: 56.1033333333
# AG_DISTRICT     YEAR
# central         2004    26.71
# east            2004    51.94
# east southeast  2004    60.03
# northeast       2004    54.46
# northwest       2004    92.82
# southeast       2004    35.38
# southwest       2004    80.70
# west            2004    62.33
# west southwest  2004    55.42
# Name: PRECIP, dtype: float64
#
#  Average: 57.7544444444
# AG_DISTRICT     YEAR
# central         2005    27.330
# east            2005    44.400
# east southeast  2005    59.250
# northeast       2005    36.760
# northwest       2005    64.730
# southeast       2005    35.750
# southwest       2005    79.090
# west            2005    46.360
# west southwest  2005    68.585
# Name: PRECIP, dtype: float64
#
#  Average: 51.3616666667
# AG_DISTRICT     YEAR
# central         2006     40.470
# east            2006     51.350
# east southeast  2006     82.230
# northeast       2006     49.660
# northwest       2006    107.460
# southeast       2006     56.990
# southwest       2006     53.830
# west            2006     57.180
# west southwest  2006     62.455
# Name: PRECIP, dtype: float64
#
#  Average: 62.4027777778
# AG_DISTRICT     YEAR
# central         2007      46.05
# east            2007      54.82
# east southeast  2007      58.66
# northeast       2007      47.63
# northwest       2007      38.14
# southeast       2007      36.65
# southwest       2007    1305.70
# west            2007      55.15
# west southwest  2007      45.87
# Name: PRECIP, dtype: float64
#
#  Average: 187.63
# AG_DISTRICT     YEAR
# central         2008     59.930
# east            2008     81.425
# east southeast  2008    115.275
# northeast       2008     49.840
# northwest       2008     54.800
# southeast       2008     60.750
# southwest       2008    128.450
# west            2008     96.550
# west southwest  2008     85.695
# Name: PRECIP, dtype: float64
#
#  Average: 81.4127777778
# AG_DISTRICT     YEAR
# central         2009     66.250
# east            2009     79.090
# east southeast  2009     92.030
# northeast       2009     53.320
# northwest       2009    715.810
# southeast       2009     59.630
# southwest       2009    127.540
# west            2009    132.790
# west southwest  2009     76.435
# Name: PRECIP, dtype: float64
#
#  Average: 155.877222222
# AG_DISTRICT     YEAR
# central         2010     45.60
# east            2010     53.81
# east southeast  2010     74.25
# northeast       2010     46.11
# northwest       2010     59.66
# southeast       2010     35.72
# southwest       2010     79.60
# west            2010    117.85
# west southwest  2010     70.44
# Name: PRECIP, dtype: float64
#
#  Average: 64.7822222222
# AG_DISTRICT     YEAR
# central         2011      52.21
# east            2011    1075.77
# east southeast  2011    1084.80
# northeast       2011      70.73
# northwest       2011      76.03
# southeast       2011      68.96
# southwest       2011      96.92
# west            2011      51.34
# west southwest  2011      65.74
# Name: PRECIP, dtype: float64
#
#  Average: 293.611111111
# AG_DISTRICT     YEAR
# central         2012     43.780
# east            2012     70.160
# east southeast  2012     68.390
# northeast       2012     51.710
# northwest       2012     54.960
# southeast       2012     49.370
# southwest       2012    106.760
# west            2012     38.520
# west southwest  2012     80.795
# Name: PRECIP, dtype: float64
#
#  Average: 62.7161111111
# AG_DISTRICT     YEAR
# central         2013     49.820
# east            2013     91.705
# east southeast  2013    101.785
# northeast       2013     90.040
# northwest       2013     85.150
# southeast       2013     83.060
# southwest       2013    133.850
# west            2013     95.700
# west southwest  2013     96.655
# Name: PRECIP, dtype: float64
#
#  Average: 91.9738888889
# AG_DISTRICT     YEAR
# central         2014     64.470
# east            2014     99.805
# east southeast  2014    100.035
# northeast       2014     51.640
# northwest       2014     67.920
# southeast       2014     66.740
# southwest       2014     99.750
# west            2014     97.790
# west southwest  2014    103.050
# Name: PRECIP, dtype: float64
#
#  Average: 83.4666666667
# AG_DISTRICT     YEAR
# central         2015     82.94
# east            2015    114.49
# east southeast  2015    107.10
# northeast       2015     65.44
# northwest       2015    117.19
# southeast       2015     36.32
# southwest       2015    142.38
# west            2015     98.24
# west southwest  2015     99.71
# Name: PRECIP, dtype: float64
#
#  Average: 95.9788888889
# AG_DISTRICT     YEAR
# central         2016     71.310
# east            2016     84.855
# east southeast  2016     92.735
# northeast       2016     95.290
# northwest       2016    872.540
# southeast       2016     65.000
# southwest       2016    107.920
# west            2016     79.250
# west southwest  2016     90.885
# Name: PRECIP, dtype: float64
#
#  Average: 173.309444444

# %%
start_year = min(weather_data['YEAR'])
end_year = max(weather_data['YEAR'])

# end year + 1 to get it to 2016
for year in range(start_year, end_year+1):
    groupby_yearly = weather_data[weather_data['YEAR'] == year].groupby(['AG_DISTRICT', 'YEAR'])
    groupby_yearly_ppt_data = groupby_yearly['NUMDAY_RAIN', 'NUM_DAYS_SNOW', 'NUM_DAYS_THNDRSTRM'].sum()
    
    print(groupby_yearly_ppt_data.head())
    print("\n")

    groupby_yearly_ppt_data = groupby_yearly_ppt_data/3
    
    # Plotting Code
    rainfall_yearly_title = str(year) + ": Average Yearly Rainfall, Snowfall, Thunderstorm received across various districts"

    ax = groupby_yearly_ppt_data.plot(kind='bar', figsize=(15, 7))
    ax.set_title(rainfall_yearly_title, fontsize=16, fontweight='bold')
    plt.xticks(rotation=45)
    plt.ylabel('Number of Days', fontsize=14)
    plt.xlabel('Agricultural Districts', fontsize=14)
    plt.legend()
    plt.show()
    #plt.savefig("results.jpg")
# Out:
#                      NUMDAY_RAIN  NUM_DAYS_SNOW  NUM_DAYS_THNDRSTRM
# AG_DISTRICT    YEAR
# central        
UMDAY_RAIN  NUM_DAYS_SNOW  NUM_DAYS_THNDRSTRM
# AG_DISTRICT    YEAR
# central        2016        239.0           49.0               115.0
# east           2016        379.0           91.0               166.0
# east southeast 2016        362.0           66.0               201.0
# northeast      2016        389.0          114.0               196.0
# northwest      2016        341.0           85.0               185.0

# %%
start_year = min(weather_data['YEAR'])
end_year = max(weather_data['YEAR'])
end_year = end_year +1

#cols = ['YEAR','TMP_HIGH', 'TMP_AVG',
#       'TMP_LOW', 'DP_HIGH', 'DP_AVG', 'DP_LOW', 'HUM_HIGH', 'HUM_AVG',
#       'HUM_LOW', 'SEALVL_HIGH', 'SEALVL_AVG', 'SEALVL_LOW', 'VIS_HIGH',
#       'VIS_AVG', 'VIS_LOW', 'WIND_HIGH', 'WIND_AVG', 'PRECIP', 'NUMDAY_RAIN',
#       'NUM_DAYS_SNOW', 'NUM_DAYS_FOG', 'NUM_DAYS_THNDRSTRM']

#model = pd.DataFrame(columns = cols)
model = pd.DataFrame()

# end year + 1 to get it to 2016
for year in range(start_year, end_year+1):
    groupby_yearly = weather_data[weather_data['YEAR'] == year].groupby(['AG_DISTRICT', 'YEAR', 'MONTH'])
    groupby_yearly_ppt_data = groupby_yearly['TMP_HIGH', 'TMP_AVG',
       'TMP_LOW', 'DP_HIGH', 'DP_AVG', 'DP_LOW', 'HUM_HIGH', 'HUM_AVG',
       'HUM_LOW', 'SEALVL_HIGH', 'SEALVL_AVG', 'SEALVL_LOW', 'VIS_HIGH',
       'VIS_AVG', 'VIS_LOW', 'WIND_HIGH', 'WIND_AVG', 'PRECIP'].mean()
    groupby_yearly_ppt_data['NUMDAY_RAIN'] = groupby_yearly['NUMDAY_RAIN'].sum()
    groupby_yearly_ppt_data['NUM_DAYS_SNOW'] = groupby_yearly['NUM_DAYS_SNOW'].sum()
    groupby_yearly_ppt_data['NUM_DAYS_FOG'] = groupby_yearly['NUM_DAYS_FOG'].sum()
    groupby_yearly_ppt_data['NUM_DAYS_THNDRSTRM'] = groupby_yearly['NUM_DAYS_THNDRSTRM'].sum()
    model = model.append(groupby_yearly_ppt_data)
    
    #print(groupby_yearly_ppt_data)
    #print("\n")

print(model.head())
model.to_csv('model.csv')
# Out:
#                         TMP_HIGH    TMP_AVG  TMP_LOW  DP_HIGH     DP_AVG  \
# AG_DISTRICT YEAR MONTH
# central     2001 ARP        75.0  46.863441     19.0     62.5  35.460753
#                  AUG        93.0  74.548387     57.0     77.0  64.806452
#                  DEC        64.0  34.193548      6.0     59.0  28.967742
#                  FEB        70.5  40.998272     -0.5     60.5  31.220622
#                  JAN        65.0  44.285924     20.0     52.5  35.129765
#
#                         DP_LOW  HUM_HIGH    HUM_AVG  HUM_LOW  SEALVL_HIGH  \
# AG_DISTRICT YEAR MONTH
# central     2001 ARP       7.0      96.5  66.329570     20.0        30.56
#                  AUG      46.0     100.0  70.870968     34.0        30.27
#                  DEC       1.0     100.0  80.419355     36.0        30.37
#                  FEB     -11.0      97.0  71.500000     20.0        30.56
#                  JAN       8.5      97.0  73.946481     30.0        30.53
#
#                                ...          VIS_HIGH   VIS_AVG  VIS_LOW  \
# AG_DISTRICT YEAR MONTH         ...
# central     2001 ARP           ...              15.0  9.855376      0.5
#                  AUG           ...              20.0  8.064516      0.0
#                  DEC           ...              20.0  7.709677      0.0
#                  FEB           ...              15.0  9.441820      0.0
#                  JAN           ...              15.0  8.614370      0.5
#
#                         WIND_HIGH  WIND_AVG  PRECIP  NUMDAY_RAIN  \
# AG_DISTRICT YEAR MONTH
# central     2001 ARP         24.0  8.330108   0.515         14.0
#                  AUG         29.0  5.516129   0.000          8.0
#                  DEC         26.0  9.129032   0.000          6.0
#                  FEB         25.0  8.340438   0.015          7.0
#                  JAN         21.0  6.843109   0.000          5.0
#
#                         NUM_DAYS_SNOW  NUM_DAYS_FOG  NUM_DAYS_THNDRSTRM
# AG_DISTRICT YEAR MONTH
# central     2001 ARP             10.0           3.0                 3.0
#                  AUG              0.0           2.0                 4.0
#                  DEC              9.0           7.0                 0.0
#                  FEB              8.0           2.0                 4.0
#                  JAN             10.0           4.0                 0.0
#
# [5 rows x 22 columns]

# %%
df = pd.read_csv('model.csv')
#print(df)

cols = [ 'YEAR', 'MONTH' , 'TMP_HIGH', 'TMP_AVG', 'TMP_LOW', 'DP_HIGH',
       'DP_AVG', 'DP_LOW', 'HUM_HIGH', 'HUM_AVG', 'HUM_LOW', 'SEALVL_HIGH',
       'SEALVL_AVG', 'SEALVL_LOW', 'VIS_HIGH', 'VIS_AVG', 'VIS_LOW',
       'WIND_HIGH', 'WIND_AVG', 'PRECIP', 'NUMDAY_RAIN', 'NUM_DAYS_SNOW',
       'NUM_DAYS_FOG', 'NUM_DAYS_THNDRSTRM']

x = []

for year in range(start_year, end_year):
    df_temp = df[df['YEAR'] == year]
    for m in months:
        df_new = df_temp[df_temp['MONTH'] == m]
        temp = list(df_new[['YEAR','TMP_HIGH', 'TMP_AVG', 'TMP_LOW', 'DP_HIGH',
       'DP_AVG', 'DP_LOW', 'HUM_HIGH', 'HUM_AVG', 'HUM_LOW', 'SEALVL_HIGH',
       'SEALVL_AVG', 'SEALVL_LOW', 'VIS_HIGH', 'VIS_AVG', 'VIS_LOW',
       'WIND_HIGH', 'WIND_AVG', 'PRECIP', 'NUMDAY_RAIN', 'NUM_DAYS_SNOW',
       'NUM_DAYS_FOG', 'NUM_DAYS_THNDRSTRM']].mean())
        temp.insert(1, m)
        x.append(temp)
        
final = pd.DataFrame(x, columns = cols)
final.insert(0, 'STATE', 'IL')
final.YEAR = final.YEAR.astype(int)
final.NUMDAY_RAIN = final.NUMDAY_RAIN.astype(int)
final.NUM_DAYS_SNOW = final.NUM_DAYS_SNOW.astype(int)
final.NUM_DAYS_FOG = final.NUM_DAYS_FOG.astype(int)
final.NUM_DAYS_THNDRSTRM = final.NUM_DAYS_THNDRSTRM.astype(int)
print (final.head())

final.to_csv('final_yearly.csv')
# Out:
#   STATE  YEAR MONTH   TMP_HIGH    TMP_AVG    TMP_LOW    DP_HIGH     DP_AVG  \
# 0    IL  2001   JAN  71.629630  54.652655  34.018519  63.500000  49.050165
# 1    IL  2001   FEB  81.370370  56.923657  27.555556  68.074074  48.770203
# 2    IL  2001   MAR  78.981481  54.888140  28.592593  65.148148  44.410042
# 3    IL  2001   ARP  82.537037  55.421243  27.111111  67.555556  43.500810
# 4    IL  2001   MAY  79.648148  53.920507  26.870370  63.555556  42.912003
#
#       DP_LOW   HUM_HIGH         ...           VIS_HIGH   VIS_AVG   VIS_LOW  \
# 0  30.796296  98.185185         ...          10.444444  7.646390  0.796296
# 1  17.518519  97.759259         ...          10.444444  8.260594  0.000000
# 2  17.962963  98.444444         ...          10.444444  8.726395  0.111111
# 3  17.870370  98.722222         ...          10.444444  9.119621  0.407407
# 4  15.333333  97.629630         ...          11.000000  8.800737  0.148148
#
#    WIND_HIGH  WIND_AVG    PRECIP  NUMDAY_RAIN  NUM_DAYS_SNOW  NUM_DAYS_FOG  \
# 0  23.388889  6.185710  0.671296            4              5             3
# 1  26.148148  6.729626  1.079630            5              5             3
# 2  27.240741  7.065699  0.931111            9              2             1
# 3  32.074074  8.908652  1.804444           12              1             1
# 4  33.648148  8.241042  1.573519           19              2             3
#
#    NUM_DAYS_THNDRSTRM
# 0                   0
# 1                   2
# 2                   2
# 3                   9
# 4                   7
#
# [5 rows x 25 columns]

# %%
final_yearly = pd.read_csv('final_yearly.csv')
final_yearly


IL_yearly_monthly = maize_data_dir + 'IL_Corn_Yearly_Month.csv'

price_yearly = pd.read_csv(IL_yearly_monthly)
price_yearly['Period'] = pd.Categorical(price_yearly['Period'], ['JAN', 'FEB', 'MAR', 'ARP', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC'])
ps = price_yearly[['Year', 'Period','Value']]

ps = ps.sort_values(['Year', 'Period'])
ps = ps.reset_index(drop=True)

#print (ps)
#print (ps['Value'])

final_yearly['Price'] = ps['Value']
print (final_yearly.head())
final_yearly.to_csv('input_model.csv')
# Out:
#    Unnamed: 0 STATE  YEAR MONTH   TMP_HIGH    TMP_AVG    TMP_LOW    DP_HIGH  \
# 0           0    IL  2001   JAN  71.629630  54.652655  34.018519  63.500000
# 1           1    IL  2001   FEB  81.370370  56.923657  27.555556  68.074074
# 2           2    IL  2001   MAR  78.981481  54.888140  28.592593  65.148148
# 3           3    IL  2001   ARP  82.537037  55.421243  27.111111  67.555556
# 4           4    IL  2001   MAY  79.648148  53.920507  26.870370  63.555556
#
#       DP_AVG     DP_LOW  ...     VIS_AVG   VIS_LOW  WIND_HIGH  WIND_AVG  \
# 0  49.050165  30.796296  ...    7.646390  0.796296  23.388889  6.185710
# 1  48.770203  17.518519  ...    8.260594  0.000000  26.148148  6.729626
# 2  44.410042  17.962963  ...    8.726395  0.111111  27.240741  7.065699
# 3  43.500810  17.870370  ...    9.119621  0.407407  32.074074  8.908652
# 4  42.912003  15.333333  ...    8.800737  0.148148  33.648148  8.241042
#
#      PRECIP  NUMDAY_RAIN  NUM_DAYS_SNOW  NUM_DAYS_FOG  NUM_DAYS_THNDRSTRM  \
# 0  0.671296            4              5             3                   0
# 1  1.079630            5              5             3                   2
# 2  0.931111            9              2             1                   2
# 3  1.804444           12              1             1                   9
# 4  1.573519           19              2             3                   7
#
#    Price
# 0   1.97
# 1   2.00
# 2   2.00
# 3   1.86
# 4   1.83
#
# [5 rows x 27 columns]

# %%
input_model = pd.read_csv('input_model.csv')
input_model.drop('Unnamed: 0', axis=1, inplace=True)
input_model.drop('Unnamed: 0.1', axis=1, inplace=True)
input_model
# Out:
#     STATE  YEAR MONTH   TMP_HIGH    TMP_AVG    TMP_LOW    DP_HIGH     DP_AVG  \
# 0      IL  2001   JAN  71.629630  54.652655  34.018519  63.500000  49.050165
# 1      IL  2001   FEB  81.370370  56.923657  27.555556  68.074074  48.770203
# 2     0.931111            9              2             1                   2
# 3     1.804444           12              1             1                   9
# 4     1.573519           19              2             3                   7
# 5     1.603519           14              5             3                   5
# 6     1.845238           10              4             2                   8
# 7     3.201429            7              0             3                   5
# 8     1.488571            6              0             3                   2
# 9     2.652857            7              0             1                   2
# 10    1.374286            6              0             1                   1
# 11    1.374286            5              5             4                   0
# 12    1.157037           11             14             3                   1
# 13    0.882963           10             13             3                   1
# 14    1.744444           24             16             6                   8
# 15    2.704630           27              2             2                  13
# 16    3.718148           35              0             1                  24
# 17    2.061296           26              0             2                  20
# 18    1.694630           18              0             1                  14
# 19    2.636296           20              0             7                  20
# 20    1.349815           15              0             5                   7
# 21    1.697593           28              0             4                   3
# 22    0.447407           18              7             1                   1
# 23    1.251111            8             12             6                   2
# 24    0.227407            6             26             2                   0
# 25    0.753333            8             23             6                   1
# 26    1.471667           23             13             9                   8
# 27    1.978333           27              1             1                  10
# 28    2.846667           36              0             2                  24
# 29    1.936667           25              0             6                  13
# ..         ...          ...            ...           ...                 ...
# 162   1.961667           29              0             6                  17
# 163   3.677778           38              0            15                  25
# 164   3.364630           25              0            10                  15
# 165   3.308889           37              1             8                  10
# 166   1.397593           20             21             3                   0
# 167   1.358889           23              6             9                   0
# 168   1.033333           19             27             6                   0
# 169   0.642963            4             32             2                   0
# 170   1.432037           23              7            11                   2
# 171   2.387222           32              0             5                  15
# 172   4.070741           43              0             4                  19
# 173   6.570926           44              0             5                  33
# 174   3.427593           33              0             6                  19
# 175   2.072407           22              0             9                  15
# 176   2.892407           23              0             4                  14
# 177   1.229630           22              0             5                   6
# 178   3.449444           31              4            10                   4
# 179   4.992778           30              8            15                  10
# 180   5.322593           12             20             5                   0
# 181   0.652778           13             19             9                   4
# 182   2.754630           39              5             6                  11
# 183  15.957593           33              1             5                  15
# 184  14.624444           43              0             6                  23
# 185   2.319815           22              0             2                  14
# 186   5.676296           39              0            13                  34
# 187   5.568333           37              0            11                  27
# 188   2.754630           28              0             8                  14
# 189   1.651296           24              0             4                  13
# 190   2.081296           21              0             8                   5
# 191   0.930370           18             21             9                   1
#
#      Price
# 0     1.97
# 1     2.00
# 2     2.00
# 3     1.86
# 4     1.83
# 5     1.95
# 6     1.99
# 7     1.94
# 8     1.85
# 9     1.91
# 10    2.06
# 11    1.92
# 12    2.01
# 13    1.98
# 14    1.98
# 15    2.00
# 16    2.05
# 17    2.24
# 18    2.47
# 19    2.50
# 20    2.36
# 21    2.33
# 22    2.37
# 23    1.96
# 24    2.37
# 25    2.35
# 26    2.36
# 27    2.43
# 28    2.39
# 29    2.20
# ..     ...
# 162   3.74
# 163   3.51
# 164   3.58
# 165   3.63
# 166   3.81
# 167   4.84
# 168   3.82
# 169   3.78
# 170   3.79
# 171   3.62
# 172   3.65
# 173   3.85
# 174   3.63
# 175   3.69
# 176   3.70
# 177   3.70
# 178   3.79
# 179   3.71
# 180   3.73
# 181   3.63
# 182   3.67
# 183   3.82
# 184   3.92
# 185   3.63
# 186   3.17
# 187   3.27
# 188   3.30
# 189   3.32
# 190   3.47
# 191   3.67
#
# [192 rows x 26 columns]
