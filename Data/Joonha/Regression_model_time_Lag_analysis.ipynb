# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# import the train test split
from sklearn.model_selection import train_test_split

#Risk-free rate for 1986 - 2016 : 9.34% ( 30-year Treasury Constant Maturity Rate at 1986 )
# Monthly discount rate = 1/1.000248 

price_file = "IL_Corn_Price.csv"
price_df = pd.read_csv(price_file)

weighted_average_df = pd.read_csv("input_model_weighted_average.csv")

# %%
len(price_df)
# Out:
# 370

# %%
# List to store results

#  Stores the name of model
model_name = []

# Get current working directory

# Uses the input file generated from preprocessing
input_file ='input_model_weighted_average.csv'

input_data = pd.read_csv(input_file)

# Making all column names UPPER CASE --> inline with the weather data file
input_data.columns = map(str.upper, input_data.columns)

# drop UNNAMED:0.1
input_data = input_data.drop('UNNAMED: 0', axis=1)

input_data.head()

# List of column names
col_names = list(input_data)

# List all column types
#input_data.dtypes

# Preprocessing

print("Shape of Original data: {}".format(input_data.shape) + "\n")

input_variables = input_data.iloc[:,4:]
print("Variables: " + str(input_variables.columns) + "\n")
print("Shape of variable data: {}".format(input_variables.shape) + "\n")
# Out:
# Shape of Original data: (370, 24)
#
# Variables: Index(['TMP_LOW', 'DP_HIGH', 'DP_AVG', 'DP_LOW', 'HUM_HIGH', 'HUM_AVG',
#        'HUM_LOW', 'SEALVL_HIGH', 'SEALVL_AVG', 'SEALVL_LOW', 'VIS_HIGH',
#        'VIS_AVG', 'VIS_LOW', 'WIND_HIGH', 'WIND_AVG', 'PRECIP', 'NUMDAY_RAIN',
#        'NUM_DAYS_SNOW', 'NUM_DAYS_FOG', 'NUM_DAYS_THNDRSTRM'],
#       dtype='object')
#
# Shape of variable data: (370, 20)

# %%
price_df
# Out:
#      Year Period     State Commodity  \
# 0    1986    JAN  ILLINOIS      CORN
# 1    1986    FEB  ILLINOIS      CORN
# 2    1986    MAR  ILLINOIS      CORN
# 3    1986    APR  ILLINOIS      CORN
# 4    1986    MAY  ILLINOIS      CORN
# 5    1986    JUN  ILLINOIS      CORN
# 6    1986    JUL  ILLINOIS      CORN
# 7    1986    AUG  ILLINOIS      CORN
# 8    1986    SEP  ILLINOIS      CORN
# 9    1986    OCT  ILLINOIS      CORN
# 10   1986    NOV  ILLINOIS      CORN
# 11   1986    DEC  ILLINOIS      CORN
# 12   1987    JAN  ILLINOIS      CORN
# 13   1987    FEB  ILLINOIS      CORN
# 14   1987    MAR  ILLINOIS      CORN
# 15   1987    APR  ILLINOIS      CORN
# 16   1987    MAY  ILLINOIS      CORN
# 17   1987    JUN  ILLINOIS      CORN
# 18   1987    JUL  ILLINOIS      CORN
# 19   1987    AUG  ILLINOIS      CORN
# 20   1987    SEP  ILLINOIS      CORN
# 21   1987    OCT  ILLINOIS      CORN
# 22   1987    NOV  ILLINOIS      CORN
# 23   1987    DEC  ILLINOIS      CORN
# 24   1988    JAN  ILLINOIS      CORN
# 25   1988    FEB  ILLINOIS      CORN
# 26   1988    MAR  ILLINOIS      CORN
# 27   1988    APR  ILLINOIS      CORN
# 28   1988    MAY  ILLINOIS      CORN
# 29   1988    JUN  ILLINOIS      CORN
# ..    ...    ...       ...       ...
# 340  2014    JUL  ILLINOIS      CORN
# 341  2014    AUG  ILLINOIS      CORN
# 342  2014    SEP  ILLINOIS      CORN
# 343  2014    OCT  ILLINOIS      CORN
# 344  2014    NOV  ILLINOIS      CORN
# 345  2014    DEC  ILLINOIS      CORN
# 346  2015    JAN  ILLINOIS      CORN
# 347  2015    FEB  ILLINOIS      CORN
# 348  2015    MAR  ILLINOIS      CORN
# 349  2015    APR  ILLINOIS      CORN
# 350  2015    MAY  ILLINOIS      CORN
# 351  2015    JUN  ILLINOIS      CORN
# 352  2015    JUL  ILLINOIS      CORN
# 353  2015    AUG  ILLINOIS      CORN
# 354  2015    SEP  ILLINOIS      CORN
# 355  2015    OCT  ILLINOIS      CORN
# 356  2015    NOV  ILLINOIS      CORN
# 357  2015    DEC  ILLINOIS      CORN
# 358  2016    JAN  ILLINOIS      CORN
# 359  2016    FEB  ILLINOIS      CORN
# 360  2016    MAR  ILLINOIS      CORN
# 361  2016    APR  ILLINOIS      CORN
# 362  2016    MAY  ILLINOIS      CORN
# 363  2016    JUN  ILLINOIS      CORN
# 364  2016    JUL  ILLINOIS      CORN
# 365  2016    AUG  ILLINOIS      CORN
# 366  2016    SEP  ILLINOIS      CORN
# 367  2016    OCT  ILLINOIS      CORN
# 368  2016    NOV  ILLINOIS      CORN
# 369  2016    DEC  ILLINOIS      CORN
#
#                                             Data Item  Value  Discounted_Value
# 0    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.35          2.350000
# 1    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.38          2.379410
# 2    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.35          2.348835
# 3    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.34          2.338259
# 4    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.45          2.447570
# 5    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.45          2.446963
# 6    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.04          2.036966
# 7    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.77          1.766930
# 8    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.52          1.516987
# 9    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.39          1.386901
# 10   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.47          1.466358
# 11   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.54          1.535804
# 12   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.53          1.525453
# 13   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.45          1.445332
# 14   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.51          1.504766
# 15   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.56          1.554207
# 16   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.72          1.713188
# 17   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.75          1.742637
# 18   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.66          1.652605
# 19   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.53          1.522807
# 20   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.53          1.522429
# 21   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.60          1.591688
# 22   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.68          1.670858
# 23   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.80          1.789761
# 24   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.81          1.799257
# 25   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.90          1.888255
# 26   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.91          1.897722
# 27   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.94          1.927051
# 28   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.03          2.015951
# 29   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.51          2.492010
# ..                                                ...    ...               ...
# 340  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   4.12          3.784923
# 341  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.74          3.434976
# 342  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.51          3.222935
# 343  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.58          3.286395
# 344  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63          3.331468
# 345  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.81          3.495797
# 346  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.82          3.504104
# 347  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.78          3.466551
# 348  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.79          3.474860
# 349  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.71          3.400669
# 350  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.62          3.317350
# 351  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.65          3.344012
# 352  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.85          3.526371
# 353  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63          3.324039
# 354  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.69          3.378144
# 355  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.70          3.386459
# 356  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.70          3.385619
# 357  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.79          3.467112
# 358  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.73          3.411377
# 359  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63          3.319096
# 360  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.67          3.354838
# 361  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.67          3.354006
# 362  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.82          3.490225
# 363  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.92          3.580704
# 364  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63          3.314982
# 365  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.17          2.894184
# 366  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.27          2.984743
# 367  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.30          3.011379
# 368  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.32          3.028878
# 369  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.47          3.164940
#
# [370 rows x 7 columns]

# %%
price = price_df.iloc[:,5]
discounted_price = price_df.iloc[:,6]

from sklearn.linear_model import LinearRegression
no_of_trials = 200

model_results = []
model_name = []
model_scores = []
for i in range(no_of_trials):
    X_train, X_test, y_train, y_test = train_test_split(input_variables.iloc[:,2:23], price, test_size=0.2)

    # Fit a linear regression model
    lr = LinearRegression().fit(X_train, y_train)
    # Store Result and Model Name
    model_scores.append(lr.score(X_test,y_test))

model_results.append(sum(model_scores)/no_of_trials)
model_name.append("Price")

model_scores = []
for i in range(no_of_trials):
    X_train, X_test, y_train, y_test = train_test_split(input_variables.iloc[:,2:23], discounted_price, test_size=0.2)

    # Fit a linear regression model
    lr = LinearRegression().fit(X_train, y_train)
    # Store Result and Model Name
    model_scores.append(lr.score(X_test,y_test))

model_results.append(sum(model_scores)/no_of_trials)
model_name.append("Price_discounted")

# %%
model_results
# Out:
# [0.3146389741342514, 0.29648125043075402]

# %%
model_name
# Out:
# ['Price', 'Price_discounted']

# %%
from matplotlib import cm
import random

# Give each bar separate color
color_code_vector = random.sample(range(1, 100), len(model_name))
reg_color_code_vector = map(lambda x: x/max(color_code_vector), color_code_vector)
reg_color_code_vector = list(reg_color_code_vector)
reg_color_code_vector
colors = cm.hsv(reg_color_code_vector)

# Expressing accuracy in percentage
model_results_percentage = list(map(lambda x: x*100, model_results))

y_pos = np.arange(len(model_name))

plt.rcdefaults() # white background, gets rid of gray
plt.figure(figsize = (20,10))
plt.bar(y_pos, model_results_percentage, align='center', alpha=0.5, width=0.2, color = colors)
plt.xticks(y_pos, model_name, fontsize = 15)
plt.ylabel('Accuracy in perecentage', fontsize=20)
plt.title('Accuracy: Linear Regression with two different prices', fontsize=22, fontweight='bold')
plt.show()

# %%
index_name = []
for i in range(13):
    index_name.append("+" + str(i) + " Months")
accuracy_df = pd.DataFrame(0,index = index_name, columns = ["Price", "Price_discounted"])
accuracy_df
# Out:
#             Price  Price_discounted
# +0 Months       0                 0
# +1 Months       0                 0
# +2 Months       0                 0
# +3 Months       0                 0
# +4 Months       0                 0
# +5 Months       0                 0
# +6 Months       0                 0
# +7 Months       0                 0
# +8 Months       0                 0
# +9 Months       0                 0
# +10 Months      0                 0
# +11 Months      0                 0
# +12 Months      0                 0

# %%
def lr_model_test(price_data, weather_data, time_lag):
    
    price_drop_range = []
    weather_drop_range = []
    for i in range(time_lag):
        price_drop_range.append(i)
        weather_drop_range.append((-1)*(i + 1))
    
    
    temp_price = price_data.drop(price_df.index[price_drop_range])
    temp_weather = weather_data.drop(weather_data.index[weather_drop_range])
    
    price = temp_price.iloc[:,5]
    discounted_price = temp_price.iloc[:,6]
    
    results = []
    model_scores = []
    for i in range(no_of_trials):
        X_train, X_test, y_train, y_test = train_test_split(temp_weather.iloc[:,2:23], price, test_size=0.2)

        # Fit a linear regression model
        lr = LinearRegression().fit(X_train, y_train)
        # Store Result and Model Name
        model_scores.append(lr.score(X_test,y_test))

    results.append(sum(model_scores)/no_of_trials)

    model_scores = []
    for i in range(no_of_trials):
        X_train, X_test, y_train, y_test = train_test_split(temp_weather.iloc[:,2:23], discounted_price, test_size=0.2)

        # Fit a linear regression model
        lr = LinearRegression().fit(X_train, y_train)
        # Store Result and Model Name
        model_scores.append(lr.score(X_test,y_test))

    results.append(sum(model_scores)/no_of_trials)
    
    return results

# %%
no_of_trials = 50
for i in range(13):
    scores = lr_model_test(price_df, input_data, i)
    accuracy_df["Price"].iloc[i] = scores[0]
    accuracy_df["Price_discounted"].iloc[i] = scores[1]

print(accuracy_df)
# Out:
#                Price  Price_discounted
# +0 Months   0.298991          0.272439
# +1 Months   0.331703          0.288583
# +2 Months   0.335325          0.317255
# +3 Months   0.339288          0.318083
# +4 Months   0.344269          0.300476
# +5 Months   0.328521          0.287302
# +6 Months   0.335507          0.321962
# +7 Months   0.322742          0.281601
# +8 Months   0.316692          0.292216
# +9 Months   0.330002          0.315954
# +10 Months  0.320389          0.307382
# +11 Months  0.312225          0.277751
# +12 Months  0.313094          0.282686

# %%
graph = accuracy_df.plot(kind='bar', figsize=(15, 7))
graph.set_title("Time Lag Analysis [Linear Regression]", fontsize=16, fontweight='bold')
plt.xticks(rotation=45)
plt.ylabel('Accuracy', fontsize=14)
plt.xlabel('Time Lags', fontsize=14)
plt.legend()
plt.show()

# %%
# Out:
#      Year Period     State Commodity  \
# 365  2016    AUG  ILLINOIS      CORN
# 366  2016    SEP  ILLINOIS      CORN
# 367  2016    OCT  ILLINOIS      CORN
# 368  2016    NOV  ILLINOIS      CORN
# 369  2016    DEC  ILLINOIS      CORN
#
#                                             Data Item  Value  Discounted_Value
# 365  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.17          2.894184
# 366  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.27          2.984743
# 367  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.30          3.011379
# 368  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.32          3.028878
# 369  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.47          3.164940
