# %%
# Library Import
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# import the train test split
from sklearn.model_selection import train_test_split

# List to store results



# Get current working directory
cwd = os.getcwd()
path = cwd + "Model_inputs/"
# Uses the input file generated from preprocessing
input_file = path + 'input_SA.csv'
input_price= path + "input_price.csv"

input_data = pd.read_csv(input_file)
input_data = input_data.iloc[:, 3:]

X_train, X_test, y_train, y_test = train_test_split(input, price, test_size=0.0)

price = pd.read_csv(input_price)



# Making all column names UPPER CASE --> inline with the weather data file
input_data.columns = map(str.upper, input_data.columns)

# List of column names
col_names = list(input_data)

#ps
#Risk-free rate for 1986 - 2016 : 9.34% ( 30-year Treasury Constant Maturity Rate at 1986 )
# Monthly discount rate = 1/1.000248 

# Splitting Data into Training and Test
# Out:
#      Year Period     State Commodity  \
# 0    1986    JAN  ILLINOIS      CORN
# 1    1986    FEB  ILLINOIS      CORN
# 2    1986    MAR  ILLINOIS      CORN
# 3    1986    APR  ILLINOIS      CORN
# 4    1986    MAY  ILLINOIS      CORN
# 5    1986    JUN  ILLINOIS      CORN
# 6    1986    JUL  ILLINOIS      CORN
# 7    1986    AUG  ILLINOIS      CORN
# 8    1986    SEP  ILLINOIS      CORN
# 9    1986    OCT  ILLINOIS      CORN
# 10   1986    NOV  ILLINOIS      CORN
# 11   1986    DEC  ILLINOIS      CORN
# 12   1987    JAN  ILLINOIS      CORN
# 13   1987    FEB  ILLINOIS      CORN
# 14   1987    MAR  ILLINOIS      CORN
# 15   1987    APR  ILLINOIS      CORN
# 16   1987    MAY  ILLINOIS      CORN
# 17   1987    JUN  ILLINOIS      CORN
# 18   1987    JUL  ILLINOIS      CORN
# 19   1987    AUG  ILLINOIS      CORN
# 20   1987    SEP  ILLINOIS      CORN
# 21   1987    OCT  ILLINOIS      CORN
# 22   1987    NOV  ILLINOIS      CORN
# 23   1987    DEC  ILLINOIS      CORN
# 24   1988    JAN  ILLINOIS      CORN
# 25   1988    FEB  ILLINOIS      CORN
# 26   1988    MAR  ILLINOIS      CORN
# 27   1988    APR  ILLINOIS      CORN
# 28   1988    MAY  ILLINOIS      CORN
# 29   1988    JUN  ILLINOIS      CORN
# ..    ...    ...       ...       ...
# 340  2014    JUL  ILLINOIS      CORN
# 341  2014    AUG  ILLINOIS      CORN
# 342  2014    SEP  ILLINOIS      CORN
# 343  2014    OCT  ILLINOIS      CORN
# 344  2014    NOV  ILLINOIS      CORN
# 345  2014    DEC  ILLINOIS      CORN
# 346  2015    JAN  ILLINOIS      CORN
# 347  2015    FEB  ILLINOIS      CORN
# 348  2015    MAR  ILLINOIS      CORN
# 349  2015    APR  ILLINOIS      CORN
# 350  2015    MAY  ILLINOIS      CORN
# 351  2015    JUN  ILLINOIS      CORN
# 352  2015    JUL  ILLINOIS      CORN
# 353  2015    AUG  ILLINOIS      CORN
# 354  2015    SEP  ILLINOIS      CORN
# 355  2015    OCT  ILLINOIS      CORN
# 356  2015    NOV  ILLINOIS      CORN
# 357  2015    DEC  ILLINOIS      CORN
# 358  2016    JAN  ILLINOIS      CORN
# 359  2016    FEB  ILLINOIS      CORN
# 360  2016    MAR  ILLINOIS      CORN
# 361  2016    APR  ILLINOIS      CORN
# 362  2016    MAY  ILLINOIS      CORN
# 363  2016    JUN  ILLINOIS      CORN
# 364  2016    JUL  ILLINOIS      CORN
# 365  2016    AUG  ILLINOIS      CORN
# 366  2016    SEP  ILLINOIS      CORN
# 367  2016    OCT  ILLINOIS      CORN
# 368  2016    NOV  ILLINOIS      CORN
# 369  2016    DEC  ILLINOIS      CORN
#
#                                             Data Item  Value  \
# 0    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.35
# 1    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.38
# 2    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.35
# 3    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.34
# 4    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.45
# 5    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.45
# 6    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.04
# 7    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.77
# 8    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.52
# 9    CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.39
# 10   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.47
# 11   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.54
# 12   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.53
# 13   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.45
# 14   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.51
# 15   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.56
# 16   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.72
# 17   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.75
# 18   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.66
# 19   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.53
# 20   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.53
# 21   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.60
# 22   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.68
# 23   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.80
# 24   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.81
# 25   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.90
# 26   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.91
# 27   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   1.94
# 28   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.03
# 29   CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   2.51
# ..                                                ...    ...
# 340  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   4.12
# 341  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.74
# 342  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.51
# 343  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.58
# 344  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63
# 345  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.81
# 346  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.82
# 347  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.78
# 348  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.79
# 349  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.71
# 350  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.62
# 351  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.65
# 352  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.85
# 353  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63
# 354  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.69
# 355  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.70
# 356  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.70
# 357  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.79
# 358  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.73
# 359  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63
# 360  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.67
# 361  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.67
# 362  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.82
# 363  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.92
# 364  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.63
# 365  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.17
# 366  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.27
# 367  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.30
# 368  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.32
# 369  CORN, GRAIN - PRICE RECEIVED, MEASURED IN $ / BU   3.47
#
#      Discounted_Value    Return
# 0            2.350000  0.000000
# 1            2.379410  0.005401
# 2            2.348835 -0.005617
# 3            2.338259 -0.001960
# 4            2.447570  0.019843
# 5            2.446963 -0.000108
# 6            2.036966 -0.079644
# 7            1.766930 -0.061765
# 8            1.516987 -0.066237
# 9            1.386901 -0.038937
# 10           1.466358  0.024195
# 11           1.535804  0.020096
# 12           1.525453 -0.002937
# 13           1.445332 -0.023431
# 14           1.504766  0.017501
# 15           1.554207  0.014040
# 16           1.713188  0.042296
# 17           1.742637  0.007402
# 18           1.652605 -0.023038
# 19           1.522807 -0.035524
# 20           1.522429 -0.000108
# 21           1.591688  0.019321
# 22           1.670858  0.021082
# 23           1.789761  0.029856
# 24           1.799257  0.002298
# 25           1.888255  0.020967
# 26           1.897722  0.002172
# 27           1.927051  0.006661
# 28           2.015951  0.019587
# 29           2.492010  0.092070
# ..                ...       ...
# 340          3.784923 -0.055456
# 341          3.434976 -0.042133
# 342          3.222935 -0.027672
# 343          3.286395  0.008468
# 344          3.331468  0.005916
# 345          3.495797  0.020911
# 346          3.504104  0.001031
# 347          3.466551 -0.004679
# 348          3.474860  0.001040
# 349          3.400669 -0.009373
# 350          3.317350 -0.010773
# 351          3.344012  0.003477
# 352          3.526371  0.023060
# 353          3.324039 -0.025662
# 354          3.378144  0.007012
# 355          3.386459  0.001068
# 356          3.385619 -0.000108
# 357          3.467112  0.010330
# 358          3.411377 -0.007038
# 359          3.319096 -0.011910
# 360          3.354838  0.004652
# 361          3.354006 -0.000108
# 362          3.490225  0.017290
# 363          3.580704  0.011115
# 364          3.314982 -0.033487
# 365          2.894184 -0.058955
# 366          2.984743  0.013381
# 367          3.011379  0.003858
# 368          3.028878  0.002516
# 369          3.164940  0.019084
#
# [370 rows x 8 columns]

# %%
# Models 

from sklearn.model_selection import cross_val_score
# Stores the performance on test set.
model_results = []
#  Stores the name of model
model_name = []

# Linear Regression
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()

accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("MLR")

#Ridge Regression
from sklearn.linear_model import Ridge
regressor = Ridge()
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("Ridge")

from sklearn.linear_model import Ridge
regressor = Ridge(alpha = 0.1)
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("Ridge0.1")

#Lasso
from sklearn.linear_model import Lasso
regressor = Lasso()
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("Lasso")

from sklearn.linear_model import Lasso
regressor = Lasso(alpha=0.0001, max_iter=100000)
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("Lasso_0.0001")

#ElasticNet
from sklearn.linear_model import ElasticNet
regressor = ElasticNet(alpha=0.1, l1_ratio=0.7,max_iter = 100000)
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("ElasticNet")

#Decision Tree
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("DT")

#Random Forest
from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("RF_10")

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 100, random_state = 0)
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("RF_100")

from sklearn.ensemble import RandomForestRegressor
regressor = RandomForestRegressor(n_estimators = 300, random_state = 0)
accuracies = cross_val_score(estimator = regressor, X = input_data, y = price["Value"], cv = 10)
model_results.append(accuracies.mean())
model_name.append("RF_300")




#Plotting
from matplotlib import cm
import random

# Give each bar separate color
color_code_vector = random.sample(range(1, 100), len(model_name))
reg_color_code_vector = map(lambda x: x/max(color_code_vector), color_code_vector)
reg_color_code_vector = list(reg_color_code_vector)
reg_color_code_vector
colors = cm.hsv(reg_color_code_vector)

# Expressing accuracy in percentage
model_results_percentage = list(map(lambda x: x*100, model_results))

y_pos = np.arange(len(model_name))

plt.rcdefaults() # white background, gets rid of gray
plt.figure(figsize = (30,15))
plt.bar(y_pos, model_results_percentage, align='center', alpha=0.5, width=0.4, color = colors)
plt.xticks(y_pos, model_name, fontsize = 12)
plt.ylabel('Accuracy in perecentage', fontsize=20)
plt.title('Accuracy: Regression Models', fontsize=22, fontweight='bold')
plt.show()

# %%
model_results
# Out:
# [-3162.1110743669219,
#  -2956.0887285044064,
#  -3113.7655021813093,
#  -98273.270249718989,
#  -3163.7840190046463,
#  -21524.66948380955,
#  -12.792004489362281,
#  -5.3628497465443719,
#  -5.346202549438912,
#  -5.4221040041264406]
